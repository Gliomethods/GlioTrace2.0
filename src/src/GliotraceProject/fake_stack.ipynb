# %%
import numpy as np
Tu8 = np.zeros((400,400,64))
Bu8 = np.zeros((400,400,64))
Vu8 = np.zeros((400,400,64))

stack = {
        "Tstack": Tu8,
        "Vstack": Bu8,
        "Bstack": Vu8,
        "delta": 0.9,
    }

stackname = "stacks_exp_148//exp_148_roi_43_stack.npz"

np.savez_compressed(
        stackname,
        **stack,
        )
